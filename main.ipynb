# %%
import pandas
from nba_api.stats.static import players
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import leaguedashplayerstats
from nba_api.stats.endpoints import leaguedashplayerstats

# %% [markdown]
# Index(['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'AGE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
#        'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#        'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#        'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#        'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#        'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK',
#        'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK'],
#       dtype='object')

# %%
def get_season_stats(season, category):
    season_stats = leaguedashplayerstats.LeagueDashPlayerStats(season=season, per_mode_detailed="PerGame")
    df = season_stats.get_data_frames()[0]
    df = df[["PLAYER_ID", "PLAYER_NAME", category]]
    return df

# %%
df = get_season_stats("2024-25", "STL")
df.sort_values("STL", ascending=False).head(20)
# Out:
#      PLAYER_ID               PLAYER_NAME  STL
# 152    1630700             Dyson Daniels  3.2
# 125    1627749           Dejounte Murray  2.4
# 494    1630178              Tyrese Maxey  2.1
# 444    1628983   Shai Gilgeous-Alexander  2.0
# 393    1631131            Oscar Tshiebwe  2.0
# 67     1642353              Cam Christie  2.0
# 334    1629029               Luka Dončić  2.0
# 13     1627936               Alex Caruso  1.9
# 177    1630529             Herbert Jones  1.9
# 458    1631106                Tari Eason  1.9
# 216    1631114            Jalen Williams  1.8
# 76     1641717             Cason Wallace  1.8
# 407     202331               Paul George  1.8
# 382     203999              Nikola Jokić  1.7
# 460    1641707          Taylor Hendricks  1.7
# 299     203484  Kentavious Caldwell-Pope  1.7
# 269    1630631             Jose Alvarado  1.7
# 158    1630532              Franz Wagner  1.7
# 314    1627739                 Kris Dunn  1.7
# ...
